# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Telco-Customer-Churn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.columns.to_list()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['TotalCharges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   object
# dtypes: object(1)
# memory usage: 55.1+ KB

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'],errors="coerce")
df['TotalCharges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7032 non-null   float64
# dtypes: float64(1)
# memory usage: 55.1 KB

# %%
df['TotalCharges'].isnull().sum()
# Out:
# 11

# %%
null = df[df['TotalCharges'].isnull()]
null
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ## Buisness Questions:

# %%
import seaborn as sns

# %% [markdown]
# ### 1-How many customer leaves company?

# %%
sns.displot(data = df,x='Churn')

# %%
(df['Churn'] == 'No').sum()
# Out:
# 5174

# %% [markdown]
# ### 2- How much months customers stays in company before leaving it

# %%
no_churn = df[df['Churn'] == 'No']
sns.displot(data= no_churn,x='tenure',kind = 'kde')

# %%
no_churn['tenure'].mode()
# Out:
# 0    72
# Name: tenure, dtype: int64

# %% [markdown]
# ### 3- Which contract type most costumers make?

# %%
sns.displot(data=df,x='Contract')

# %%
sns.displot(data=no_churn,x='Contract')

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
sns.kdeplot(data = df,x='TotalCharges',hue = 'Contract')
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %%
df.groupby('Contract').sum()['TotalCharges']
# Out:
# Contract
# Month-to-month    5305861.5
# One year          4467053.5
# Two year          6283253.7
# Name: TotalCharges, dtype: float64

# %% [markdown]
# ### 4- Is partners has most outcomes?

# %%
df['Partner'].value_counts()
# Out:
# No     3641
# Yes    3402
# Name: Partner, dtype: int64

# %%
df.groupby('Partner').sum()
# Out:
#          SeniorCitizen  tenure  MonthlyCharges  TotalCharges
# Partner
# No                 569   85046       225541.75     5767671.0
# Yes                573  142944       230574.85    10288497.7

# %%
sns.kdeplot(data = df,x='TotalCharges',hue='Partner')
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %%
sns.displot(data=df,x = 'PaymentMethod',hue = 'SeniorCitizen')

# %%
sns.kdeplot(data=df,x='TotalCharges',hue='SeniorCitizen')
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %%
df['SeniorCitizen'].value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
df.groupby('SeniorCitizen').sum()['TotalCharges']
# Out:
# SeniorCitizen
# 0    12846617.45
# 1     3209551.25
# Name: TotalCharges, dtype: float64

# %% [markdown]
# ### 5- Which service is most used?

# %%
df[(df['PhoneService'] != 'No')].value_counts().sum()
# Out:
# 6352

# %%
df[(df['InternetService'] != 'No')].value_counts().sum()
# Out:
# 5512

# %% [markdown]
# ### 6- Which service has most outcomes?

# %%
df[(df['PhoneService'] != 'No')]['TotalCharges'].sum()
# Out:
# 15035873.75

# %%
df[(df['InternetService'] != 'No')]['TotalCharges'].sum()
# Out:
# 15045033.8

# %% [markdown]
# ### 7- Which gender has more outcome?

# %%
sns.displot(data = df,x ='gender')

# %%
sns.kdeplot(data = df,x = 'TotalCharges',hue = 'gender')
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %%
df.groupby('gender').sum()['TotalCharges']
# Out:
# gender
# Female    7952354.2
# Male      8103814.5
# Name: TotalCharges, dtype: float64

# %% [markdown]
# ### 8- Which contract type customers stay longer?

# %%
no_churn.groupby('Contract').mean()['tenure']
# Out:
# Contract
# Month-to-month    21.033333
# One year          41.674063
# Two year          56.602914
# Name: tenure, dtype: float64

# %%
sns.kdeplot(data = no_churn,x = 'tenure',hue = 'Contract')
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Density'>

# %% [markdown]
# ### 9- How many customers has multiple lines and how its effect in outcome?

# %%
df['MultipleLines'].value_counts()
# Out:
# No                  3390
# Yes                 2971
# No phone service     682
# Name: MultipleLines, dtype: int64

# %%
df.groupby('MultipleLines').sum()['TotalCharges']
# Out:
# MultipleLines
# No                   4569184.90
# No phone service     1020294.95
# Yes                 10466688.85
# Name: TotalCharges, dtype: float64

# %%
sns.kdeplot(data = df,x = 'TotalCharges',hue = 'MultipleLines')
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %% [markdown]
# ### 10- How contract type effect on monthlycharges?

# %%
df.groupby('Contract').mean()['MonthlyCharges']
# Out:
# Contract
# Month-to-month    66.398490
# One year          65.048608
# Two year          60.770413
# Name: MonthlyCharges, dtype: float64

# %%
sns.kdeplot(data= df,x ='MonthlyCharges',hue = 'Contract')
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>
